# %%
import pandas as pd

# %%
file_path = pd.read_csv(r"C:\Users\nengo\OneDrive\Documents\netflix_titles.csv\netflix_titles.csv")
file_path.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#removing NaN values
colums = ["show_id", "type", "title", "director", "cast", "country", "date_added", "release_year", "rating", "duration", "listed_in", "description"]
file_path[colums] = file_path[colums].fillna(" ")
file_path.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans
# 4      s5  TV Show           Kota Factory
#
#                                                 cast        country  \
# 0                                                     United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
# Specifically, it retrieves rows starting from the 1000th row (inclusive) up to the 1049th row (exclusive). 
file_path.iloc[1000:1050]
# Out:
#      show_id     type                                      title  \
# 1000   s1001    Movie                                   Wild Dog
# 1001   s1002    Movie                                   Oloibiri
# 1002   s1003    Movie                               Tell Me When
# 1003   s1004  TV Show                                       Zero
# 1004   s1005  TV Show                         Izzy's Koala World
# 1005   s1006    Movie         Keymon and Nani in Space Adventure
# 1006   s1007    Movie                   Motu Patlu Dino Invasion
# 1007   s1008    Movie                Motu Patlu in Octupus World
# 1008   s1009    Movie                    Motu Patlu VS Robo Kids
# 1009   s1010    Movie            Rudra: Secret of the Black Moon
# 1010   s1011    Movie            Rudra: The Rise of King Pharaoh
# 1011   s1012    Movie                               Free to Play
# 1012   s1013  TV Show                   Luis Miguel - The Series
# ...

# %%
#array or a pandas Series that contains all the distinct values found in the 'rating' column of the DataFrame 

file_path['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', ' ',
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
#get an array or Series that contains the unique values present in the 'rating'
#column of file_path, with '74 min', '84 min', '66 min', ' ', and 'NR' replaced by 'UR'.
file_path['rating'].replace({'74 min': 'UR', '84 min': "UR", "66 min": "UR", ' ':"UR", "NR": "UR"}, inplace=True)
file_path['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', 'UR', 'TV-Y7-FV'], dtype=object)

# %%
movie_list = []
Tv_show_list= []
file_path = pd.read_csv(r"C:\Users\nengo\OneDrive\Documents\netflix_titles.csv\netflix_titles.csv")

for i in range(len(file_path)):
    if file_path['type'].iloc[i] == "TV Show":
        Tv_show_list.append(i)
    else:
        movie_list.append(i)

        
film_movie = file_path.loc[movie_list, : ]
show = file_path.loc[Tv_show_list, :  ]

film_movie=film_movie.set_index([pd.Index(range(0,len(film_movie)))])
show =show.set_index([pd.Index(range(0,len(show)))])

# %%
film_movie
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 1         s7  Movie  My Little Pony: A New Generation
# 2         s8  Movie                           Sankofa
# 3        s10  Movie                      The Starling
# 4        s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 6126   s8802  Movie                           Zinzana
# 6127   s8803  Movie                            Zodiac
# 6128   s8805  Movie                        Zombieland
# 6129   s8806  Movie                              Zoom
# 6130   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 1     Robert Cullen, José Luis Ucha
# 2                      Haile Gerima
# 3                    Theodore Melfi
# 4               Christian Schwochow
# ...                             ...
# 6126                Majid Al Ansari
# ...
